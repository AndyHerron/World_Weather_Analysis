# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | touros
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | katobu
# Processing Record 4 of Set 1 | san nicolas
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | cascais
# Processing Record 7 of Set 1 | mbuji-mayi
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | marondera
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | qrendi
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | yarada
# Processing Record 16 of Set 1 | basco
# Processing Record 17 of Set 1 | boyolangu
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | saint-joseph
# Processing Record 21 of Set 1 | soyo
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | coihaique
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | port blair
# Processing Record 33 of Set 1 | juneau
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | megion
# Processing Record 36 of Set 1 | rafsanjan
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | el astillero
# Processing Record 40 of Set 1 | tilichiki
# Processing Record 41 of Set 1 | totness
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | roma
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | codajas
# Processing Record 46 of Set 1 | ust-uda
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | ubinskoye
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | arriaga
# Processing Record 2 of Set 2 | deputatskiy
# Processing Record 3 of Set 2 | cururupu
# Processing Record 4 of Set 2 | lentekhi
# Processing Record 5 of Set 2 | chernyshevskiy
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | vila franca do campo
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | nouakchott
# Processing Record 11 of Set 2 | sfantu gheorghe
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | bosaso
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | lesozavodsk
# Processing Record 21 of Set 2 | faanui
# Processing Record 22 of Set 2 | haapiti
# Processing Record 23 of Set 2 | cody
# Processing Record 24 of Set 2 | west odessa
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 2 | saurimo
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | atar
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | hargeysa
# Processing Record 37 of Set 2 | alugan
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | port pirie
# Processing Record 40 of Set 2 | turukhansk
# Processing Record 41 of Set 2 | mandalgovi
# Processing Record 42 of Set 2 | prince rupert
# Processing Record 43 of Set 2 | orlik
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | luwuk
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | qasigiannguit
# Processing Record 49 of Set 2 | whitehorse
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | porto belo
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | benguela
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | eyl
# Processing Record 6 of Set 3 | batavia
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | kiunga
# Processing Record 11 of Set 3 | nathdwara
# Processing Record 12 of Set 3 | mareeba
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | malakal
# Processing Record 18 of Set 3 | sao paulo de olivenca
# Processing Record 19 of Set 3 | tobermory
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | ostrovnoy
# Processing Record 23 of Set 3 | morant bay
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | magetan
# City not found. Skipping...
# Processing Record 31 of Set 3 | debre tabor
# Processing Record 32 of Set 3 | makakilo city
# Processing Record 33 of Set 3 | faya
# Processing Record 34 of Set 3 | sterling
# Processing Record 35 of Set 3 | mokrous
# Processing Record 36 of Set 3 | salalah
# Processing Record 37 of Set 3 | beloha
# Processing Record 38 of Set 3 | henties bay
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | shenjiamen
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | akonolinga
# Processing Record 44 of Set 3 | masuguru
# Processing Record 45 of Set 3 | muisne
# Processing Record 46 of Set 3 | parambu
# Processing Record 47 of Set 3 | pizarro
# Processing Record 48 of Set 3 | quelimane
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | xuddur
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | ndioum
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | havoysund
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | palmital
# Processing Record 9 of Set 4 | japura
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | sweetwater
# Processing Record 12 of Set 4 | sulangan
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | ohara
# Processing Record 15 of Set 4 | north myrtle beach
# Processing Record 16 of Set 4 | port hardy
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | kahului
# Processing Record 20 of Set 4 | mildura
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | aljezur
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | weston
# Processing Record 29 of Set 4 | taltal
# Processing Record 30 of Set 4 | murray bridge
# Processing Record 31 of Set 4 | sinnamary
# Processing Record 32 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 4 | hermanus
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | pirovskoye
# Processing Record 37 of Set 4 | atasu
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | srednekolymsk
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | sola
# Processing Record 42 of Set 4 | akalkot
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | tera
# Processing Record 46 of Set 4 | mezen
# Processing Record 47 of Set 4 | waspan
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 5 | gorontalo
# Processing Record 2 of Set 5 | kajaani
# Processing Record 3 of Set 5 | novo aripuana
# Processing Record 4 of Set 5 | nola
# Processing Record 5 of Set 5 | verkhnyaya inta
# Processing Record 6 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 5 | naron
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | dodge city
# Processing Record 12 of Set 5 | nishihara
# Processing Record 13 of Set 5 | nome
# Processing Record 14 of Set 5 | sibu
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | ambulu
# Processing Record 17 of Set 5 | camacha
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | auki
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | butaritari
# Processing Record 22 of Set 5 | ghanzi
# Processing Record 23 of Set 5 | liminangcong
# City not found. Skipping...
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | brufut
# Processing Record 26 of Set 5 | vagamo
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | katsuura
# Processing Record 29 of Set 5 | karasuk
# Processing Record 30 of Set 5 | leshukonskoye
# Processing Record 31 of Set 5 | sao joao da barra
# Processing Record 32 of Set 5 | kangaatsiaq
# Processing Record 33 of Set 5 | umm kaddadah
# Processing Record 34 of Set 5 | caravelas
# Processing Record 35 of Set 5 | krzeszowice
# Processing Record 36 of Set 5 | wahiawa
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | pakokku
# Processing Record 39 of Set 5 | akersberga
# Processing Record 40 of Set 5 | albertville
# Processing Record 41 of Set 5 | honiara
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | sikonge
# Processing Record 44 of Set 5 | lufilufi
# Processing Record 45 of Set 5 | yellowknife
# Processing Record 46 of Set 5 | castanos
# Processing Record 47 of Set 5 | rorvik
# Processing Record 48 of Set 5 | chihuahua
# Processing Record 49 of Set 5 | adamas
# Processing Record 50 of Set 5 | adre
# Processing Record 1 of Set 6 | shimoda
# Processing Record 2 of Set 6 | tiruchchendur
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | batagay-alyta
# Processing Record 5 of Set 6 | reyes
# Processing Record 6 of Set 6 | zhigansk
# Processing Record 7 of Set 6 | aksarka
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 6 | hithadhoo
# Processing Record 11 of Set 6 | sioux lookout
# Processing Record 12 of Set 6 | mumford
# Processing Record 13 of Set 6 | tumut
# Processing Record 14 of Set 6 | merritt island
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | quatre cocos
# Processing Record 18 of Set 6 | baker city
# Processing Record 19 of Set 6 | trelew
# Processing Record 20 of Set 6 | lakes entrance
# Processing Record 21 of Set 6 | kuliyapitiya
# Processing Record 22 of Set 6 | bohicon
# Processing Record 23 of Set 6 | mehamn
# Processing Record 24 of Set 6 | san-pedro
# Processing Record 25 of Set 6 | manggar
# Processing Record 26 of Set 6 | nioro
# Processing Record 27 of Set 6 | putten
# Processing Record 28 of Set 6 | beira
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | port augusta
# Processing Record 32 of Set 6 | elizabeth city
# Processing Record 33 of Set 6 | alta
# Processing Record 34 of Set 6 | weihai
# Processing Record 35 of Set 6 | ulaangom
# Processing Record 36 of Set 6 | tuktoyaktuk
# Processing Record 37 of Set 6 | verkhoyansk
# Processing Record 38 of Set 6 | gaoua
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | deder
# Processing Record 41 of Set 6 | ribeira grande
# Processing Record 42 of Set 6 | iberia
# Processing Record 43 of Set 6 | la ronge
# Processing Record 44 of Set 6 | husavik
# Processing Record 45 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 6 | betare oya
# Processing Record 47 of Set 6 | barguzin
# Processing Record 48 of Set 6 | saldanha
# Processing Record 49 of Set 6 | black river
# Processing Record 50 of Set 6 | sarakhs
# Processing Record 1 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 7 | san cristobal
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | khasan
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | peniche
# Processing Record 7 of Set 7 | kodiak
# Processing Record 8 of Set 7 | progreso
# Processing Record 9 of Set 7 | trairi
# Processing Record 10 of Set 7 | komsomolskiy
# Processing Record 11 of Set 7 | termiz
# Processing Record 12 of Set 7 | marienburg
# Processing Record 13 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 15 of Set 7 | oranjestad
# Processing Record 16 of Set 7 | chapais
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 20 of Set 7 | lavrentiya
# Processing Record 21 of Set 7 | sorong
# Processing Record 22 of Set 7 | goalpara
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | linhares
# Processing Record 25 of Set 7 | juybar
# Processing Record 26 of Set 7 | rawson
# Processing Record 27 of Set 7 | broken hill
# Processing Record 28 of Set 7 | fernley
# Processing Record 29 of Set 7 | kiama
# Processing Record 30 of Set 7 | aklavik
# Processing Record 31 of Set 7 | si satchanalai
# Processing Record 32 of Set 7 | barcelona
# Processing Record 33 of Set 7 | killybegs
# Processing Record 34 of Set 7 | turayf
# Processing Record 35 of Set 7 | mbandaka
# Processing Record 36 of Set 7 | san lawrenz
# Processing Record 37 of Set 7 | catamarca
# Processing Record 38 of Set 7 | romny
# Processing Record 39 of Set 7 | calvinia
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | sao jose da coroa grande
# Processing Record 42 of Set 7 | avera
# Processing Record 43 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 7 | pevek
# Processing Record 45 of Set 7 | khuzdar
# Processing Record 46 of Set 7 | mayor pablo lagerenza
# Processing Record 47 of Set 7 | tuatapere
# Processing Record 48 of Set 7 | kuusankoski
# Processing Record 49 of Set 7 | sahuaripa
# Processing Record 50 of Set 7 | sabang
# Processing Record 1 of Set 8 | canutama
# Processing Record 2 of Set 8 | baruun-urt
# Processing Record 3 of Set 8 | iranshahr
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | luzhou
# Processing Record 6 of Set 8 | luba
# Processing Record 7 of Set 8 | broome
# Processing Record 8 of Set 8 | gravdal
# Processing Record 9 of Set 8 | serenje
# Processing Record 10 of Set 8 | san pedro
# Processing Record 11 of Set 8 | nakonde
# Processing Record 12 of Set 8 | araouane
# Processing Record 13 of Set 8 | kanniyakumari
# Processing Record 14 of Set 8 | barkhera
# Processing Record 15 of Set 8 | esperance
# Processing Record 16 of Set 8 | chuy
# Processing Record 17 of Set 8 | sao filipe
# Processing Record 18 of Set 8 | kinablangan
# Processing Record 19 of Set 8 | olinda
# Processing Record 20 of Set 8 | akola
# Processing Record 21 of Set 8 | ibicarai
# Processing Record 22 of Set 8 | kitimat
# Processing Record 23 of Set 8 | laizhou
# Processing Record 24 of Set 8 | zheleznodorozhnyy
# Processing Record 25 of Set 8 | bauchi
# Processing Record 26 of Set 8 | suhbaatar
# Processing Record 27 of Set 8 | nehe
# Processing Record 28 of Set 8 | coos bay
# Processing Record 29 of Set 8 | tessalit
# Processing Record 30 of Set 8 | saint anthony
# Processing Record 31 of Set 8 | te anau
# Processing Record 32 of Set 8 | yei
# Processing Record 33 of Set 8 | batagay
# Processing Record 34 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 8 | san ramon
# Processing Record 36 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 8 | nelson bay
# Processing Record 38 of Set 8 | russell
# Processing Record 39 of Set 8 | zhezkazgan
# Processing Record 40 of Set 8 | pitimbu
# Processing Record 41 of Set 8 | stokmarknes
# Processing Record 42 of Set 8 | cabo san lucas
# Processing Record 43 of Set 8 | saint-pierre
# Processing Record 44 of Set 8 | salinopolis
# Processing Record 45 of Set 8 | ziro
# Processing Record 46 of Set 8 | sokoni
# Processing Record 47 of Set 8 | general pico
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | mozarlandia
# Processing Record 50 of Set 8 | sakaiminato
# Processing Record 1 of Set 9 | chongwe
# Processing Record 2 of Set 9 | scarborough
# Processing Record 3 of Set 9 | denpasar
# Processing Record 4 of Set 9 | irituia
# Processing Record 5 of Set 9 | betioky
# Processing Record 6 of Set 9 | dukat
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | chukhloma
# Processing Record 9 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | havre-saint-pierre
# Processing Record 14 of Set 9 | buala
# Processing Record 15 of Set 9 | dingle
# Processing Record 16 of Set 9 | haines junction
# Processing Record 17 of Set 9 | fujin
# Processing Record 18 of Set 9 | svobodnyy
# Processing Record 19 of Set 9 | klishkivtsi
# Processing Record 20 of Set 9 | gawler
# Processing Record 21 of Set 9 | nemuro
# Processing Record 22 of Set 9 | muros
# Processing Record 23 of Set 9 | lircay
# Processing Record 24 of Set 9 | kyren
# Processing Record 25 of Set 9 | meulaboh
# Processing Record 26 of Set 9 | teguldet
# Processing Record 27 of Set 9 | honningsvag
# Processing Record 28 of Set 9 | kabo
# Processing Record 29 of Set 9 | kirakira
# Processing Record 30 of Set 9 | santa cruz
# Processing Record 31 of Set 9 | chopda
# Processing Record 32 of Set 9 | west wendover
# Processing Record 33 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 9 | forestville
# Processing Record 35 of Set 9 | hay river
# Processing Record 36 of Set 9 | edgewater
# Processing Record 37 of Set 9 | calabozo
# Processing Record 38 of Set 9 | riyadh
# Processing Record 39 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 9 | lorengau
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | salisbury
# Processing Record 44 of Set 9 | omboue
# Processing Record 45 of Set 9 | morgan city
# Processing Record 46 of Set 9 | ambatofinandrahana
# Processing Record 47 of Set 9 | auxerre
# Processing Record 48 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 9 | garissa
# Processing Record 50 of Set 9 | dovers
# Processing Record 1 of Set 10 | nara
# Processing Record 2 of Set 10 | cockburn town
# Processing Record 3 of Set 10 | tongren
# Processing Record 4 of Set 10 | langxiang
# Processing Record 5 of Set 10 | sao desiderio
# Processing Record 6 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 10 | batticaloa
# Processing Record 8 of Set 10 | bizhbulyak
# Processing Record 9 of Set 10 | conceicao do araguaia
# Processing Record 10 of Set 10 | muroto
# Processing Record 11 of Set 10 | orotukan
# Processing Record 12 of Set 10 | molo
# Processing Record 13 of Set 10 | monrovia
# Processing Record 14 of Set 10 | teya
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | kloulklubed
# Processing Record 17 of Set 10 | ugoofaaru
# Processing Record 18 of Set 10 | carrollton
# Processing Record 19 of Set 10 | buraydah
# Processing Record 20 of Set 10 | kalnciems
# Processing Record 21 of Set 10 | kashi
# Processing Record 22 of Set 10 | alice springs
# Processing Record 23 of Set 10 | lumphat
# Processing Record 24 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 10 | pokosnoye
# Processing Record 27 of Set 10 | hovd
# Processing Record 28 of Set 10 | taoudenni
# Processing Record 29 of Set 10 | khartoum
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | calamar
# Processing Record 32 of Set 10 | yerbogachen
# Processing Record 33 of Set 10 | kaka
# Processing Record 34 of Set 10 | nikologory
# Processing Record 35 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 10 | numan
# Processing Record 37 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | puerto carreno
# Processing Record 40 of Set 10 | san lorenzo
# Processing Record 41 of Set 10 | batemans bay
# Processing Record 42 of Set 10 | lasa
# Processing Record 43 of Set 10 | riachao das neves
# Processing Record 44 of Set 10 | chumikan
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | grindavik
# Processing Record 47 of Set 10 | tual
# Processing Record 48 of Set 10 | ambilobe
# Processing Record 49 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 10 | novyye burasy
# Processing Record 1 of Set 11 | labelle
# Processing Record 2 of Set 11 | palembang
# Processing Record 3 of Set 11 | mount isa
# Processing Record 4 of Set 11 | mantua
# Processing Record 5 of Set 11 | port macquarie
# Processing Record 6 of Set 11 | alagir
# Processing Record 7 of Set 11 | santa maria
# Processing Record 8 of Set 11 | lokosovo
# Processing Record 9 of Set 11 | halifax
# Processing Record 10 of Set 11 | san carlos
# Processing Record 11 of Set 11 | mana
# Processing Record 12 of Set 11 | menongue
# Processing Record 13 of Set 11 | antalaha
# Processing Record 14 of Set 11 | bambanglipuro
# Processing Record 15 of Set 11 | kuito
# Processing Record 16 of Set 11 | bud
# Processing Record 17 of Set 11 | alenquer
# Processing Record 18 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 11 | sayyan
# Processing Record 20 of Set 11 | ndiekro
# City not found. Skipping...
# Processing Record 21 of Set 11 | los algarrobos
# Processing Record 22 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 23 of Set 11 | sete
# Processing Record 24 of Set 11 | nicholasville
# Processing Record 25 of Set 11 | anloga
# Processing Record 26 of Set 11 | kizukuri
# Processing Record 27 of Set 11 | charters towers
# Processing Record 28 of Set 11 | muscat
# Processing Record 29 of Set 11 | nazas
# Processing Record 30 of Set 11 | kalmunai
# Processing Record 31 of Set 11 | acarau
# Processing Record 32 of Set 11 | sawtell
# Processing Record 33 of Set 11 | oranjemund
# Processing Record 34 of Set 11 | shitanjing
# Processing Record 35 of Set 11 | abidjan
# Processing Record 36 of Set 11 | pangnirtung
# Processing Record 37 of Set 11 | chipinge
# Processing Record 38 of Set 11 | nador
# Processing Record 39 of Set 11 | berdyaush
# Processing Record 40 of Set 11 | vila
# Processing Record 41 of Set 11 | guadalupe
# Processing Record 42 of Set 11 | porteirinha
# Processing Record 43 of Set 11 | abonnema
# Processing Record 44 of Set 11 | rundu
# Processing Record 45 of Set 11 | mount gambier
# Processing Record 46 of Set 11 | chara
# Processing Record 47 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 48 of Set 11 | manyana
# Processing Record 49 of Set 11 | rehti
# Processing Record 50 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 12 | ripky
# Processing Record 2 of Set 12 | djambala
# Processing Record 3 of Set 12 | sinjai
# Processing Record 4 of Set 12 | hawkhead
# Processing Record 5 of Set 12 | san quintin
# Processing Record 6 of Set 12 | huron
# Processing Record 7 of Set 12 | taree
# Processing Record 8 of Set 12 | tonantins
# Processing Record 9 of Set 12 | skjervoy
# Processing Record 10 of Set 12 | dicabisagan
# Processing Record 11 of Set 12 | pangkalanbuun
# Processing Record 12 of Set 12 | sur
# Processing Record 13 of Set 12 | cariamanga
# Processing Record 14 of Set 12 | port ellen
# City not found. Skipping...
# Processing Record 15 of Set 12 | sembe
# Processing Record 16 of Set 12 | lishui
# Processing Record 17 of Set 12 | siderno
# Processing Record 18 of Set 12 | san andres
# Processing Record 19 of Set 12 | mount pleasant
# Processing Record 20 of Set 12 | kavaratti
# Processing Record 21 of Set 12 | tromso
# Processing Record 22 of Set 12 | apac
# Processing Record 23 of Set 12 | chipata
# Processing Record 24 of Set 12 | constanta
# Processing Record 25 of Set 12 | lianran
# Processing Record 26 of Set 12 | kasempa
# Processing Record 27 of Set 12 | jiwani
# Processing Record 28 of Set 12 | carauari
# Processing Record 29 of Set 12 | florence
# Processing Record 30 of Set 12 | tabou
# Processing Record 31 of Set 12 | ust-kut
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | san ignacio
# Processing Record 34 of Set 12 | stornoway
# Processing Record 35 of Set 12 | tutoia
# Processing Record 36 of Set 12 | kutum
# Processing Record 37 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 12 | kijang
# Processing Record 39 of Set 12 | tucurui
# Processing Record 40 of Set 12 | punta alta
# Processing Record 41 of Set 12 | bin qirdan
# Processing Record 42 of Set 12 | puerto del rosario
# Processing Record 43 of Set 12 | dali
# Processing Record 44 of Set 12 | qaqortoq
# Processing Record 45 of Set 12 | maniitsoq
# Processing Record 46 of Set 12 | marsh harbour
# Processing Record 47 of Set 12 | kawalu
# Processing Record 48 of Set 12 | forbes
# Processing Record 49 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 12 | asau
# Processing Record 1 of Set 13 | amahai
# Processing Record 2 of Set 13 | balabac
# Processing Record 3 of Set 13 | xining
# Processing Record 4 of Set 13 | pacifica
# Processing Record 5 of Set 13 | carbonia
# Processing Record 6 of Set 13 | vardo
# Processing Record 7 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 13 | heihe
# Processing Record 9 of Set 13 | bandarbeyla
# Processing Record 10 of Set 13 | palu
# Processing Record 11 of Set 13 | mnogovershinnyy
# Processing Record 12 of Set 13 | labuhan
# Processing Record 13 of Set 13 | bumba
# Processing Record 14 of Set 13 | prieska
# Processing Record 15 of Set 13 | nhulunbuy
# Processing Record 16 of Set 13 | gat
# Processing Record 17 of Set 13 | bontang
# Processing Record 18 of Set 13 | santo tomas
# Processing Record 19 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 13 | mecca
# Processing Record 21 of Set 13 | simoes
# Processing Record 22 of Set 13 | xapuri
# Processing Record 23 of Set 13 | kampot
# Processing Record 24 of Set 13 | kuryk
# Processing Record 25 of Set 13 | kanigiri
# Processing Record 26 of Set 13 | dombarovskiy
# Processing Record 27 of Set 13 | kuusamo
# Processing Record 28 of Set 13 | pandan
# Processing Record 29 of Set 13 | ola
# Processing Record 30 of Set 13 | bolbec
# Processing Record 31 of Set 13 | baculin
# Processing Record 32 of Set 13 | yatou
# Processing Record 33 of Set 13 | dudinka
# Processing Record 34 of Set 13 | half moon bay
# Processing Record 35 of Set 13 | sobolevo
# Processing Record 36 of Set 13 | straumen
# Processing Record 37 of Set 13 | surt
# Processing Record 38 of Set 13 | lagoa
# Processing Record 39 of Set 13 | abu dhabi
# Processing Record 40 of Set 13 | rafai
# Processing Record 41 of Set 13 | corowa
# Processing Record 42 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 13 | shiloh
# Processing Record 44 of Set 13 | ahipara
# Processing Record 45 of Set 13 | palana
# Processing Record 46 of Set 13 | celestun
# Processing Record 47 of Set 13 | bukachacha
# Processing Record 48 of Set 13 | turbat
# Processing Record 49 of Set 13 | kjopsvik
# Processing Record 50 of Set 13 | katherine
# Processing Record 1 of Set 14 | benghazi
# Processing Record 2 of Set 14 | sabha
# Processing Record 3 of Set 14 | labrea
# Processing Record 4 of Set 14 | kuala terengganu
# Processing Record 5 of Set 14 | banyo
# Processing Record 6 of Set 14 | ocos
# Processing Record 7 of Set 14 | vidim
# Processing Record 8 of Set 14 | san luis
# Processing Record 9 of Set 14 | nicoya
# Processing Record 10 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 11 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 14 | landskrona
# Processing Record 13 of Set 14 | buin
# Processing Record 14 of Set 14 | kolo
# Processing Record 15 of Set 14 | bajil
# Processing Record 16 of Set 14 | maragogi
# Processing Record 17 of Set 14 | hualmay
# Processing Record 18 of Set 14 | alyangula
# Processing Record 19 of Set 14 | schoningen
# Processing Record 20 of Set 14 | margate
# Processing Record 21 of Set 14 | paredon
# Processing Record 22 of Set 14 | jiangyan
# Processing Record 23 of Set 14 | bairiki
# Processing Record 24 of Set 14 | de-kastri
# Processing Record 25 of Set 14 | tura
# Processing Record 26 of Set 14 | kununurra
# Processing Record 27 of Set 14 | walvis bay
# Processing Record 28 of Set 14 | karibib
# Processing Record 29 of Set 14 | puri
# Processing Record 30 of Set 14 | alliston
# Processing Record 31 of Set 14 | mostovskoy
# Processing Record 32 of Set 14 | saint-augustin
# Processing Record 33 of Set 14 | burica
# City not found. Skipping...
# Processing Record 34 of Set 14 | sumedang
# Processing Record 35 of Set 14 | sechura
# Processing Record 36 of Set 14 | concordia
# Processing Record 37 of Set 14 | rosamorada
# Processing Record 38 of Set 14 | verkhoturye
# Processing Record 39 of Set 14 | luanda
# Processing Record 40 of Set 14 | molteno
# Processing Record 41 of Set 14 | genhe
# Processing Record 42 of Set 14 | emerald
# Processing Record 43 of Set 14 | rameswaram
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | tagusao
# Processing Record 46 of Set 14 | zaysan
# Processing Record 47 of Set 14 | antigonish
# Processing Record 48 of Set 14 | bagrami
# Processing Record 49 of Set 14 | grand-santi
# Processing Record 50 of Set 14 | santa cruz de la palma
# Processing Record 1 of Set 15 | bathsheba
# Processing Record 2 of Set 15 | candolim
# Processing Record 3 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 15 | lewisporte
# Processing Record 5 of Set 15 | terrace
# Processing Record 6 of Set 15 | los llanos de aridane
# Processing Record 7 of Set 15 | poletayevo
# Processing Record 8 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 9 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 11 of Set 15 | shetpe
# Processing Record 12 of Set 15 | tomohon
# Processing Record 13 of Set 15 | havelock
# Processing Record 14 of Set 15 | tsiroanomandidy
# Processing Record 15 of Set 15 | volovo
# Processing Record 16 of Set 15 | mokhsogollokh
# Processing Record 17 of Set 15 | freeport
# Processing Record 18 of Set 15 | mawlaik
# Processing Record 19 of Set 15 | bay city
# Processing Record 20 of Set 15 | vanavara
# Processing Record 21 of Set 15 | markala
# Processing Record 22 of Set 15 | mogocha
# Processing Record 23 of Set 15 | kamachumu
# Processing Record 24 of Set 15 | nisia floresta
# Processing Record 25 of Set 15 | mogadishu
# Processing Record 26 of Set 15 | kimbe
# Processing Record 27 of Set 15 | dong hoi
# Processing Record 28 of Set 15 | monte escobedo
# Processing Record 29 of Set 15 | ixtapa
# Processing Record 30 of Set 15 | nha trang
# Processing Record 31 of Set 15 | yarovoye
# Processing Record 32 of Set 15 | vavuniya
# Processing Record 33 of Set 15 | brigham city
# Processing Record 34 of Set 15 | cukai
# Processing Record 35 of Set 15 | dandong
# Processing Record 36 of Set 15 | la palma
# Processing Record 37 of Set 15 | kaeo
# Processing Record 38 of Set 15 | hidalgotitlan
# Processing Record 39 of Set 15 | el vigia
# Processing Record 40 of Set 15 | atka
# City not found. Skipping...
# Processing Record 41 of Set 15 | pundaguitan
# Processing Record 42 of Set 15 | port lincoln
# Processing Record 43 of Set 15 | sosva
# Processing Record 44 of Set 15 | port hueneme
# Processing Record 45 of Set 15 | sena madureira
# Processing Record 46 of Set 15 | ossora
# Processing Record 47 of Set 15 | terra santa
# Processing Record 48 of Set 15 | karasjok
# Processing Record 49 of Set 15 | chase
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 680        El Vigia      VE   8.6219  -71.6506     75.00        91
# 681     Pundaguitan      PH   6.3711  126.1689     83.30        76
# 682    Port Lincoln      AU -34.7333  135.8667     64.51        46
# 683           Sosva      RU  59.1766   61.8558     12.63        95
# 684    Port Hueneme      US  34.1478 -119.1951     59.54        47
# 685  Sena Madureira      BR  -9.0656  -68.6569     73.94        99
# 686          Ossora      RU  59.2353  163.0719     -8.46        86
# 687     Terra Santa      BR  -2.1042  -56.4869     74.95        94
# 688        Karasjok      NO  69.4719   25.5112     24.91        90
# 689           Chase      CA  50.8165 -119.6857     26.13        96
#
#      Cloudiness  Wind Speed Current Description
# 680          89        1.57     overcast clouds
# 681          31       10.09    scattered clouds
# 682         100       20.54     overcast clouds
# 683         100        7.09          light snow
# 684           1        8.05           clear sky
# 685         100        2.42       moderate rain
# 686           1        6.78           clear sky
# 687         100        1.48     overcast clouds
# 688          99       12.80     overcast clouds
# 689          99        2.35          light snow

# %%
# reorder the columns in the dataframe
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.tail()
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 685  Sena Madureira      BR  -9.0656  -68.6569     73.94        99
# 686          Ossora      RU  59.2353  163.0719     -8.46        86
# 687     Terra Santa      BR  -2.1042  -56.4869     74.95        94
# 688        Karasjok      NO  69.4719   25.5112     24.91        90
# 689           Chase      CA  50.8165 -119.6857     26.13        96
#
#      Cloudiness  Wind Speed Current Description
# 685         100        2.42       moderate rain
# 686           1        6.78           clear sky
# 687         100        1.48     overcast clouds
# 688          99       12.80     overcast clouds
# 689          99        2.35          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
